# %%
import pandas as pd
import numpy as np


from bs4 import BeautifulSoup
import requests
import world_bank_data as wb

# %%
carsdf = pd.read_csv("./vehicles.csv")
carsdf.head(10)

cleaneddf=carsdf.fillna("filled")
#carsdf.columns
#carsdf[carsdf.columns[10:20]]
#carsdf[carsdf.columns[70:80]]
cleaneddf
dfcars_selection = carsdf[["make","id","model","fuelType","fuelType1","fuelType2","evMotor", "cityE","co2","co2TailpipeAGpm","co2TailpipeGpm","comb08", "combA08", "combE","highway08","highwayA08","highwayE","UCity","UCityA","UHighway","UHighwayA" ]]
# Out:
# c:\users\picav\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dfselection = cleaneddf[["make","id","model","year","fuelType","evMotor","cityE","co2","co2TailpipeGpm","comb08", "combE","highway08","highwayE","UCity","UHighway"]]
dfselection[dfselection["fuelType"]=="Electricity"][["make","model"]]
# Out:
#          make                              model
# 7138   Nissan                           Altra EV
# 7139   Toyota                            RAV4 EV
# 8143   Toyota                            RAV4 EV
# 8144     Ford                              Th!nk
# 8146     Ford             Explorer USPS Electric
# ...       ...                                ...
# 36719   Tesla  Model X Performance (22in Wheels)
# 36720   Tesla             Model Y Long Range AWD
# 36721   Tesla            Model Y Performance AWD
# 36727     Kia                      Soul Electric
# 36728   Tesla            Model X Long Range Plus
#
# [252 rows x 2 columns]

# %%
dfselection[dfselection["fuelType"]=="Electricity"]
# Out:
#          make     id                              model  year     fuelType  \
# 7138   Nissan  16423                           Altra EV  2000  Electricity
# 7139   Toyota  16424                            RAV4 EV  2000  Electricity
# 8143   Toyota  17328                            RAV4 EV  2001  Electricity
# 8144     Ford  17329                              Th!nk  2001  Electricity
# 8146     Ford  17330             Explorer USPS Electric  2001  Electricity
# ...       ...    ...                                ...   ...          ...
# 36719   Tesla  43405  Model X Performance (22in Wheels)  2021  Electricity
# 36720   Tesla  43406             Model Y Long Range AWD  2021  Electricity
# 36721   Tesla  43407            Model Y Performance AWD  2021  Electricity
# 36727     Kia  43412                      Soul Electric  2020  Electricity
# 36728   Tesla  43413            Model X Long Range Plus  2020  Electricity
#
#                          evMotor    cityE  co2  co2TailpipeGpm  comb08  \
# 7138          62 KW AC Induction  41.0000    0             0.0      85
# 7139                    50 KW DC  41.0000    0             0.0      72
# 8143                    50 KW DC  41.0000    0             0.0      72
# 8144          27 KW AC Induction  46.0000    0             0.0      65
# 8146          67 KW AC Induction  75.0000    0             0.0      39
# ...                          ...      ...  ...             ...     ...
# 36719  151 and 273 kW AC 3-Phase  38.0795    0             0.0      86
# 36720   69 and 201 kW AC 3-Phase  25.6464    0             0.0     125
# 36721  133 and 179 kW AC 3-Phase  29.3322    0             0.0     111
# 36727             201 kW AC PMSM  25.9849    0             0.0     114
# 36728  193 and 205 kW AC 3-Phase  31.0865    0             0.0     105
#
#          combE  highway08  highwayE     UCity  UHighway
# 7138   40.0000         91   37.0000  116.2069  129.6154
# 7139   47.0000         64   53.0000  116.2069   91.0811
# 8143   47.0000         64   53.0000  116.2069   91.0811
# 8144   52.0000         58   59.0000  105.3125   82.1951
# 8146   87.0000         33  102.0000   62.4074   46.8056
# ...        ...        ...       ...       ...       ...
# 36719  39.2815         83   40.7505  119.0000  111.2000
# 36720  27.0455        117   28.7556  171.1000  152.6000
# 36721  30.4938        106   31.9135  149.6000  137.5000
# 36727  29.1732        101   33.0701  185.3000  145.6000
# 36728  32.1566        101   33.4644  153.4000  142.5000
#
# [252 rows x 15 columns]

# %%
motortype = dfselection[(dfselection["fuelType"]=="Electricity") & (dfselection["year"]>2018)]["evMotor"].value_counts()
motortype
# Out:
# 193 and 205 kW AC 3-Phase                          11
# 211 kW AC 3-Phase                                   8
# 147 and 211 kW AC 3-Phase                           5
# 150 kW ACPM                                         4
# 160 kW DCPM                                         4
# 100 kW AC PMSM                                      3
# 110 kW DCPM                                         2
# 151 and 273 kW AC 3-Phase                           2
# 193 (front) 193 (rear) (75 kW-hr battery pack)      2
# 205 and 375 kW AC 3-Phase                           2
# 147 and 188 kW AC 3-Phase                           2
# 193 (front) 375 (rear) (100 kW-hr battery pack)     2
# 60 KW AC Synchronous                                2
# 135 kW AC Induction                                 2
# 125 kW AC Induction                                 2
# 150 kW IPMSM                                        2
# 135 kW DCPM                                         2
# 141 and 172 kW Asynchron 3-Phase                    2
# 150 kW AC PMSM                                      2
# 147 and 147 kW AC 3-Phase                           2
# 193 (front), 205/375 (rear) kW ACPM                 2
# 193 (front) 193 (rear) (100 kW-hr battery pack)     2
# 158 and 203 kW AC 3-Phase                           1
# 88 kW AC PMSM                                       1
# 158 and 219 kW AC 3-Phase                           1
# 201 kW AC PMSM                                      1
# 98 and 195 kW AC 3-Phase                            1
# 82 kW AC Induction                                  1
# 180 and 189 kW AC 3-Phase                           1
# 120 kW ACPM                                         1
# 75 kW DCPM                                          1
# 69 and 201 kW AC 3-Phase                            1
# 131 and 190 kW AC 3-Phase                           1
# 120 kW AC PMSM                                      1
# 193 and 375 kW AC 3-Phase                           1
# 133 and 179 kW AC 3-Phase                           1
# 120 and 170 kW ACPM                                 1
# 81 kW AC PMSM                                       1
# 170 kW ACPM                                         1
# Name: evMotor, dtype: int64

# %%
model_el_name=dfselection[(dfselection["fuelType"]=="Electricity") & (dfselection["year"]>2018)][["make","model"]]

model_el_name
# Out:
#              make                              model
# 33394     Hyundai                     Ioniq Electric
# 33544   Chevrolet                            Bolt EV
# 33615     Hyundai                      Kona Electric
# 33818         Kia                      Soul Electric
# 33819  Volkswagen                             e-Golf
# ...           ...                                ...
# 36719       Tesla  Model X Performance (22in Wheels)
# 36720       Tesla             Model Y Long Range AWD
# 36721       Tesla            Model Y Performance AWD
# 36727         Kia                      Soul Electric
# 36728       Tesla            Model X Long Range Plus
#
# [84 rows x 2 columns]

# %%
#model_el_name.to_csv("elec_car_names.csv")

# %%
allcars_2018 = dfselection[dfselection["year"]>2018]
allcars_2018
# Out:
#                  make     id                         model  year     fuelType  \
# 32814            Jeep  39861                  Cherokee FWD  2019     Midgrade
# 32815            Jeep  39862                  Cherokee 4WD  2019     Midgrade
# 32816            Jeep  39863  Cherokee 4WD Active Drive II  2019     Midgrade
# 32817            Jeep  39864        Cherokee Trailhawk 4WD  2019     Midgrade
# 32826       Chevrolet  39872                      Corvette  2019      Premium
# ...               ...    ...                           ...   ...          ...
# 36723     Lamborghini  43409       Aventador Sian Roadster  2020      Premium
# 36725     Lamborghini  43410          Aventador Sian Coupe  2020      Premium
# 36726  RUF Automobile  43411  TURBO12/CTR3/CTR ANNIVERSARY  2020      Premium
# 36727             Kia  43412                 Soul Electric  2020  Electricity
# 36728           Tesla  43413       Model X Long Range Plus  2020  Electricity
#
#                          evMotor    cityE  co2  co2TailpipeGpm  comb08  \
# 32814                     filled   0.0000  387           387.0      23
# 32815                     filled   0.0000  400           400.0      22
# 32816                     filled   0.0000  416           416.0      21
# 32817                     filled   0.0000  432           432.0      21
# 32826                     filled   0.0000  465           465.0      19
# ...                          ...      ...  ...             ...     ...
# 36723                     filled   0.0000  861           861.0      10
# 36725                     filled   0.0000  861           861.0      10
# 36726                     filled   0.0000  497           497.0      18
# 36727             201 kW AC PMSM  25.9849    0             0.0     114
# 36728  193 and 205 kW AC 3-Phase  31.0865    0             0.0     105
#
#          combE  highway08  highwayE     UCity  UHighway
# 32814   0.0000         29    0.0000   24.9000   40.9961
# 32815   0.0000         27    0.0000   24.2000   38.8000
# 32816   0.0000         26    0.0000   23.1000   37.0483
# 32817   0.0000         24    0.0000   22.8996   34.7000
# 32826   0.0000         25    0.0000   20.0270   35.4602
# ...        ...        ...       ...       ...       ...
# 36723   0.0000         14    0.0000   10.0492   19.1669
# 36725   0.0000         14    0.0000   10.0492   19.1669
# 36726   0.0000         20    0.0000   20.2300   27.6300
# 36727  29.1732        101   33.0701  185.3000  145.6000
# 36728  32.1566        101   33.4644  153.4000  142.5000
#
# [3417 rows x 15 columns]

# %%
# starting formulas calculation



# 1 mile = 1.60934 km
# 1MPG = 0.425144 kilometer per liter
#def mile_to_km(x):
#    x = x*1.60934
#    return x

#allcars_2018["cityE"]=allcars_2018["cityE"]/1.60934 ## alredy executed dont run again

# %%
#next column miles to kms co2 column
#allcars_2018["co2"]=allcars_2018["co2"]/1.60934 already done. commented to not rerun

# %%
allcars_2018["evMotor"].value_counts()
# Out:
# filled                       2999
# 48V Li-Ion                     99
# 259V Li-Ion                    17
# 34 and 65kW 3-phase Sync.      14
# 288V Ni-MH                     14
#                              ...
# 82 kW AC Induction              1
# 131 and 190 kW AC 3-Phase       1
# 686V Li-Ion                     1
# 36 kW DCPM                      1
# 158 and 203 kW AC 3-Phase       1
# Name: evMotor, Length: 101, dtype: int64

# %%
allcars_2018["co2_per_km"]=allcars_2018["co2TailpipeGpm"]/1.60934 #already done. commented to not rerun
# Out:
# <ipython-input-12-a840c3915329>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allcars_2018["co2_per_km"]=allcars_2018["co2TailpipeGpm"]/1.60934 #already done. commented to not rerun

# %%
allcars_2018["cityE_100km"]=allcars_2018["cityE"]/1.60934
# Out:
# <ipython-input-38-ff31c5c8d29c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allcars_2018["cityE_100km"]=allcars_2018["cityE"]/1.60934

# %%
#MPG transform / by 2.3521458
allcars_2018["comb08_per_km"]=allcars_2018["comb08"]/2.3521458 #already done. commented to not rerun
# Out:
# <ipython-input-13-592c2fe8bfd2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allcars_2018["comb08_per_km"]=allcars_2018["comb08"]/2.3521458 #already done. commented to not rerun

# %%
#convert in kms
allcars_2018["combE_per_km"]=allcars_2018["combE"]/1.60934 #already done. commented to not rerun
# Out:
# <ipython-input-14-ce7dc782450f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allcars_2018["combE_per_km"]=allcars_2018["combE"]/1.60934 #already done. commented to not rerun

# %%
#MPG transform
allcars_2018["highway08_per_lkm"]=allcars_2018["highway08"]/2.3521458 #already done. commented to not rerun
# Out:
# <ipython-input-15-921db6086c8c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allcars_2018["highway08_per_lkm"]=allcars_2018["highway08"]/2.3521458 #already done. commented to not rerun

# %%
#convert in kms
allcars_2018["highwayE_per_km"]=allcars_2018["highwayE"]/1.60934 #already done. commented to not rerun
# Out:
# <ipython-input-16-8f53b9873577>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allcars_2018["highwayE_per_km"]=allcars_2018["highwayE"]/1.60934 #already done. commented to not rerun

# %%
#MPG transform
allcars_2018["UCity_per_lkm"]=allcars_2018["UCity"]/2.3521458 #already done. commented to not rerun
# Out:
# <ipython-input-17-41712a23e1d2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allcars_2018["UCity_per_lkm"]=allcars_2018["UCity"]/2.3521458 #already done. commented to not rerun

# %%
#MPG transform
allcars_2018["UHighway_per_lkm"]=allcars_2018["UHighway"]/2.3521458 #already done. commented to not rerun
# Out:
# <ipython-input-18-a2b3ce7cb484>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allcars_2018["UHighway_per_lkm"]=allcars_2018["UHighway"]/2.3521458 #already done. commented to not rerun

# %%
#convert in kms
allcars_2018["co2_km"]=allcars_2018["co2"]/1.60934 #already done. commented to not rerun
# Out:
# <ipython-input-19-afa3f4f68a34>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   allcars_2018["co2_km"]=allcars_2018["co2"]/1.60934 #already done. commented to not rerun

# %%
allcars_2018
# Out:
#                  make     id                         model  year     fuelType  \
# 32814            Jeep  39861                  Cherokee FWD  2019     Midgrade
# 32815            Jeep  39862                  Cherokee 4WD  2019     Midgrade
# 32816            Jeep  39863  Cherokee 4WD Active Drive II  2019     Midgrade
# 32817            Jeep  39864        Cherokee Trailhawk 4WD  2019     Midgrade
# 32826       Chevrolet  39872                      Corvette  2019      Premium
# ...               ...    ...                           ...   ...          ...
# 36723     Lamborghini  43409       Aventador Sian Roadster  2020      Premium
# 36725     Lamborghini  43410          Aventador Sian Coupe  2020      Premium
# 36726  RUF Automobile  43411  TURBO12/CTR3/CTR ANNIVERSARY  2020      Premium
# 36727             Kia  43412                 Soul Electric  2020  Electricity
# 36728           Tesla  43413       Model X Long Range Plus  2020  Electricity
#
#                          evMotor    cityE  co2  co2TailpipeGpm  comb08  ...  \
# 32814                     filled   0.0000  387           387.0      23  ...
# 32815                     filled   0.0000  400           400.0      22  ...
# 32816                     filled   0.0000  416           416.0      21  ...
# 32817                     filled   0.0000  432           432.0      21  ...
# 32826                     filled   0.0000  465           465.0      19  ...
# ...                          ...      ...  ...             ...     ...  ...
# 36723                     filled   0.0000  861           861.0      10  ...
# 36725                     filled   0.0000  861           861.0      10  ...
# 36726                     filled   0.0000  497           497.0      18  ...
# 36727             201 kW AC PMSM  25.9849    0             0.0     114  ...
# 36728  193 and 205 kW AC 3-Phase  31.0865    0             0.0     105  ...
#
#        UHighway  co2_per_km  comb08_per_km  combE_per_km  highway08_per_lkm  \
# 32814   40.9961  240.471249       9.778305      0.000000          12.329168
# 32815   38.8000  248.549095       9.353162      0.000000          11.478880
# 32816   37.0483  258.491058       8.928018      0.000000          11.053737
# 32817   34.7000  268.433022       8.928018      0.000000          10.203449
# 32826   35.4602  288.938323       8.077731      0.000000          10.628593
# ...         ...         ...            ...           ...                ...
# 36723   19.1669  535.001926       4.251437      0.000000           5.952012
# 36725   19.1669  535.001926       4.251437      0.000000           5.952012
# 36726   27.6300  308.822250       7.652587      0.000000           8.502874
# 36727  145.6000    0.000000      48.466383     18.127431          42.939515
# 36728  142.5000    0.000000      44.640090     19.981235          42.939515
#
#        highwayE_per_km  UCity_per_lkm  UHighway_per_lkm      co2_km  \
# 32814         0.000000      10.586078         17.429234  240.471249
# 32815         0.000000      10.288478         16.495576  248.549095
# 32816         0.000000       9.820820         15.750852  258.491058
# 32817         0.000000       9.735621         14.752487  268.433022
# 32826         0.000000       8.514353         15.075681  288.938323
# ...                ...            ...               ...         ...
# 36723         0.000000       4.272354          8.148687  535.001926
# 36725         0.000000       4.272354          8.148687  535.001926
# 36726         0.000000       8.600657         11.746721  308.822250
# 36727        20.548859      78.779130         61.900925    0.000000
# 36728        20.793866      65.217046         60.582979    0.000000
#
#        cityE_100km
# 32814     0.000000
# 32815     0.000000
# 32816     0.000000
# 32817     0.000000
# 32826     0.000000
# ...            ...
# 36723     0.000000
# 36725     0.000000
# 36726     0.000000
# 36727    16.146308
# 36728    19.316304
#
# [3417 rows x 24 columns]

# %%
allcars_2018= allcars_2018.drop(columns=["cityE","co2","co2TailpipeGpm", 'comb08', 'combE', 'highway08', 'highwayE', 'UCity','UHighway'])

# %%
cars2018_c=allcars_2018

# %%
cars2018_c=cars2018_c.reset_index()
cars2018_c=cars2018_c.drop(columns='index')
cars2018_c
# Out:
#                 make     id                         model  year     fuelType  \
# 0               Jeep  39861                  Cherokee FWD  2019     Midgrade
# 1               Jeep  39862                  Cherokee 4WD  2019     Midgrade
# 2               Jeep  39863  Cherokee 4WD Active Drive II  2019     Midgrade
# 3               Jeep  39864        Cherokee Trailhawk 4WD  2019     Midgrade
# 4          Chevrolet  39872                      Corvette  2019      Premium
# ...              ...    ...                           ...   ...          ...
# 3412     Lamborghini  43409       Aventador Sian Roadster  2020      Premium
# 3413     Lamborghini  43410          Aventador Sian Coupe  2020      Premium
# 3414  RUF Automobile  43411  TURBO12/CTR3/CTR ANNIVERSARY  2020      Premium
# 3415             Kia  43412                 Soul Electric  2020  Electricity
# 3416           Tesla  43413       Model X Long Range Plus  2020  Electricity
#
#                         evMotor  co2_per_km  comb08_per_km  combE_per_km  \
# 0                        filled  240.471249       9.778305      0.000000
# 1                        filled  248.549095       9.353162      0.000000
# 2                        filled  258.491058       8.928018      0.000000
# 3                        filled  268.433022       8.928018      0.000000
# 4                        filled  288.938323       8.077731      0.000000
# ...                         ...         ...            ...           ...
# 3412                     filled  535.001926       4.251437      0.000000
# 3413                     filled  535.001926       4.251437      0.000000
# 3414                     filled  308.822250       7.652587      0.000000
# 3415             201 kW AC PMSM    0.000000      48.466383     18.127431
# 3416  193 and 205 kW AC 3-Phase    0.000000      44.640090     19.981235
#
#       highway08_per_lkm  highwayE_per_km  UCity_per_lkm  UHighway_per_lkm  \
# 0             12.329168         0.000000      10.586078         17.429234
# 1             11.478880         0.000000      10.288478         16.495576
# 2             11.053737         0.000000       9.820820         15.750852
# 3             10.203449         0.000000       9.735621         14.752487
# 4             10.628593         0.000000       8.514353         15.075681
# ...                 ...              ...            ...               ...
# 3412           5.952012         0.000000       4.272354          8.148687
# 3413           5.952012         0.000000       4.272354          8.148687
# 3414           8.502874         0.000000       8.600657         11.746721
# 3415          42.939515        20.548859      78.779130         61.900925
# 3416          42.939515        20.793866      65.217046         60.582979
#
#           co2_km  cityE_100km
# 0     240.471249     0.000000
# 1     248.549095     0.000000
# 2     258.491058     0.000000
# 3     268.433022     0.000000
# 4     288.938323     0.000000
# ...          ...          ...
# 3412  535.001926     0.000000
# 3413  535.001926     0.000000
# 3414  308.822250     0.000000
# 3415    0.000000    16.146308
# 3416    0.000000    19.316304
#
# [3417 rows x 15 columns]

# %%
#------------------------electricity sections down------------------------------------

# %%
# Electricity production from renewable sources, excluding hydroelectric (% of total)
url='https://data.worldbank.org/indicator/EG.ELC.RNWX.ZS'

#Electricity production from renewable sources, excluding hydroelectric (kWh)
url='https://data.worldbank.org/indicator/EG.ELC.RNWX.KH'

#Electricity production from oil sources (% of total)
url='https://data.worldbank.org/indicator/EG.ELC.PETR.ZS'

#Electricity production from nuclear sources (% of total)
url='https://data.worldbank.org/indicator/EG.ELC.NUCL.ZS'

#Electricity production from coal sources (% of total)
url='https://data.worldbank.org/indicator/EG.ELC.COAL.ZS'

#Electricity production from oil, gas and coal sources (% of total)
url='https://data.worldbank.org/indicator/EG.ELC.FOSL.ZS'

#Electricity production from natural gas sources (% of total)
url='https://data.worldbank.org/indicator/EG.ELC.NGAS.ZS'

#Electricity production from hydroelectric sources (% of total)
url='https://data.worldbank.org/indicator/EG.ELC.HYRO.ZS'

#------------ELECTRICITY PRODUCTION BREAKDOWN--------------------#UPPER

#Electric power transmission and distribution losses (% of output)
url='https://data.worldbank.org/indicator/EG.ELC.LOSS.ZS'

#------------ACCESS TO ELECTRICITY BREAKDOWN----------------------#LOWER

#Access to electricity (% of population)
url='https://data.worldbank.org/indicator/EG.ELC.ACCS.ZS'

#Access to electricity, urban (% of urban population)
url='https://data.worldbank.org/indicator/EG.ELC.ACCS.UR.ZS'

#Access to electricity, rural (% of rural population)
url='https://data.worldbank.org/indicator/EG.ELC.ACCS.RU.ZS'

# %%
#FETCHING FOR VARIOUS TABLES

elect_prod_renew_sourc_per = pd.DataFrame(wb.get_series('EG.ELC.RNWX.ZS', mrv=1))
elect_prod_renew_sourc_kwh = pd.DataFrame(wb.get_series('EG.ELC.RNWX.KH', mrv=1))
elect_prod_oil_sourc = pd.DataFrame(wb.get_series('EG.ELC.PETR.ZS', mrv=1))
elect_prod_nucl_sourc = pd.DataFrame(wb.get_series('EG.ELC.NUCL.ZS', mrv=1))
elect_prod_coal_sourc = pd.DataFrame(wb.get_series('EG.ELC.COAL.ZS', mrv=1))
elect_prod_oilgascoal_sourc = pd.DataFrame(wb.get_series('EG.ELC.FOSL.ZS', mrv=1))
elect_prod_natgas_sourc = pd.DataFrame(wb.get_series('EG.ELC.NGAS.ZS', mrv=1))
elect_prod_hydro_sourc = pd.DataFrame(wb.get_series('EG.ELC.HYRO.ZS', mrv=1))
elect_power_transm_loss = pd.DataFrame(wb.get_series('EG.ELC.LOSS.ZS', mrv=1))
elect_access = pd.DataFrame(wb.get_series('EG.ELC.ACCS.ZS', mrv=1))
elect_access_urban = pd.DataFrame(wb.get_series('EG.ELC.ACCS.UR.ZS', mrv=1))
elect_access_rural = pd.DataFrame(wb.get_series('EG.ELC.ACCS.RU.ZS', mrv=1))

# %%
#REMOVING COLUMNS FROM INDEXES
elect_prod_renew_sourc_per.reset_index(inplace=True)
elect_prod_renew_sourc_kwh.reset_index(inplace=True)
elect_prod_oil_sourc.reset_index(inplace=True)
elect_prod_nucl_sourc.reset_index(inplace=True)
elect_prod_coal_sourc.reset_index(inplace=True)
elect_prod_oilgascoal_sourc.reset_index(inplace=True)
elect_prod_natgas_sourc.reset_index(inplace=True)
elect_prod_hydro_sourc .reset_index(inplace=True)
elect_power_transm_loss.reset_index(inplace=True)
elect_access.reset_index(inplace=True)
elect_access_urban.reset_index(inplace=True)
elect_access_rural.reset_index(inplace=True)

# %%
#RENAMING VALUE COLUMNS
elect_prod_renew_sourc_per=elect_prod_renew_sourc_per.rename(columns={"EG.ELC.RNWX.ZS": "Percentage"})
elect_prod_renew_sourc_kwh=elect_prod_renew_sourc_kwh.rename(columns={"EG.ELC.RNWX.KH": "KWH"})
elect_prod_oil_sourc=elect_prod_oil_sourc.rename(columns={"EG.ELC.PETR.ZS": "Percentage"})
elect_prod_nucl_sourc=elect_prod_nucl_sourc.rename(columns={"EG.ELC.NUCL.ZS": "Percentage"})
elect_prod_coal_sourc=elect_prod_coal_sourc.rename(columns={"EG.ELC.COAL.ZS": "Percentage"})
elect_prod_oilgascoal_sourc=elect_prod_oilgascoal_sourc.rename(columns={"EG.ELC.FOSL.ZS": "Percentage"})
elect_prod_natgas_sourc = elect_prod_natgas_sourc.rename(columns={"EG.ELC.NGAS.ZS": "Percentage"})
elect_prod_hydro_sourc = elect_prod_hydro_sourc.rename(columns={"EG.ELC.HYRO.ZS": "Percentage"})
elect_power_transm_loss=elect_power_transm_loss.rename(columns={"EG.ELC.LOSS.ZS": "Percentage"})
elect_access=elect_access.rename(columns={"EG.ELC.ACCS.ZS": "Percentage"})
elect_access_urban=elect_access_urban.rename(columns={"EG.ELC.ACCS.UR.ZS": "Percentage"})
elect_access_rural=elect_access_rural.rename(columns={"EG.ELC.ACCS.RU.ZS": "Percentage"})

# %%
#DROPPING DUMMY COLUMNS
elect_prod_renew_sourc_per=elect_prod_renew_sourc_per.drop(columns=['Series'])
elect_prod_renew_sourc_kwh=elect_prod_renew_sourc_kwh.drop(columns=['Series'])
elect_prod_oil_sourc=elect_prod_oil_sourc.drop(columns=['Series'])
elect_prod_nucl_sourc=elect_prod_nucl_sourc.drop(columns=['Series'])
elect_prod_coal_sourc=elect_prod_coal_sourc.drop(columns=['Series'])
elect_prod_oilgascoal_sourc=elect_prod_oilgascoal_sourc.drop(columns=['Series'])
elect_prod_natgas_sourc = elect_prod_natgas_sourc.drop(columns=['Series'])
elect_prod_hydro_sourc = elect_prod_hydro_sourc.drop(columns=['Series'])
elect_power_transm_loss=elect_power_transm_loss.drop(columns=['Series'])
elect_access=elect_access.drop(columns=['Series'])
elect_access_urban=elect_access_urban.drop(columns=['Series'])
elect_access_rural=elect_access_rural.drop(columns=['Series'])

# %%
#elect_prod_renew_sourc_per
#elect_prod_renew_sourc_kwh
#elect_prod_oil_sourc
#elect_prod_nucl_sourc
#elect_prod_coal_sourc
#elect_prod_oilgascoal_sourc
#elect_power_transm_loss
#elect_access
#elect_access_urban
#elect_access_rural

# %%
result=pd.merge(elect_access, elect_access_rural, on="Country")

table_elec_access=pd.merge(result,elect_access_urban, on="Country")

table_elec_access=table_elec_access.rename(columns={"Percentage_x": "Electricity Access WW", "Percentage_y":"Electricity Access Rural" , "Percentage":"Electricity Access Urban"})

table_elec_access=table_elec_access.drop(columns=['Year','Year_y'])

table_elec_access=table_elec_access.rename(columns={"Year_x": "Year"})

# %%
combination=pd.merge(elect_prod_renew_sourc_per, elect_prod_oil_sourc, on="Country")

combination


combination=combination.drop(columns=['Year_y'])

combination=combination.rename(columns={"Year_x": "Year", "Percentage_y":"Oil Sources %" , "Percentage_x":"Renewable Sources %"})

combination2=pd.merge(combination, elect_prod_nucl_sourc, on="Country")

combination2=combination2.drop(columns=['Year_y'])

combination2=combination2.rename(columns={"Percentage": "Nuclear Sources %"})

combination3=pd.merge(combination2, elect_prod_coal_sourc, on="Country")

combination3=combination3.drop(columns=['Year'])

combination4=combination3.rename(columns={"Year_x": "Year", "Percentage": "Coal Sources %"})

combination5=pd.merge(combination4, elect_prod_natgas_sourc, on="Country")

combination5=combination5.drop(columns=['Year_y'])

combination5=combination5.rename(columns={"Percentage": "Natural Gas Sources %", "Year_x": "Year"})

combination6=pd.merge(combination5, elect_prod_hydro_sourc, on="Country")

combination6=combination6.drop(columns=['Year_y'])

table_elec_source_breakdown=combination6.rename(columns={"Percentage": "Hydroelectric Sources %", "Year_x": "Year"})

# %%
table_elec_source_breakdown.iloc[200:250]
# Out:
#                             Country  Year  Renewable Sources %  Oil Sources %  \
# 200                        Paraguay  2015             0.000000       0.001794
# 201                            Peru  2015             3.589563       1.403080
# 202                     Philippines  2015            14.899348       7.142077
# 203                          Poland  2015            12.687643       1.288784
# 204                        Portugal  2015            30.639028       2.558452
# 205                     Puerto Rico  2015                  NaN            NaN
# 206                           Qatar  2015             0.000000       0.000000
# 207                         Romania  2015            14.515640       0.719032
# 208              Russian Federation  2015             0.091027       0.946958
# 209                          Rwanda  2015                  NaN            NaN
# 210                           Samoa  2015                  NaN            NaN
# 211                      San Marino  2015                  NaN            NaN
# 212           Sao Tome and Principe  2015                  NaN            NaN
# 213                    Saudi Arabia  2015             0.000296      20.406342
# 214                         Senegal  2015             1.769912      83.615676
# 215                          Serbia  2015             0.093097       0.074478
# 216                      Seychelles  2015                  NaN            NaN
# 217                    Sierra Leone  2015                  NaN            NaN
# 218                       Singapore  2015             1.820887       0.698205
# 219       Sint Maarten (Dutch part)  2015                  NaN            NaN
# 220                 Slovak Republic  2015             8.163112       1.441874
# 221                        Slovenia  2015             3.691705       0.114733
# 222                 Solomon Islands  2015                  NaN            NaN
# 223                         Somalia  2015                  NaN            NaN
# 224                    South Africa  2015             1.930403       0.074168
# 225                     South Sudan  2015             0.606061      99.393939
# 226                           Spain  2015            24.820009       6.206442
# 227                       Sri Lanka  2015             3.193749      17.819754
# 228             St. Kitts and Nevis  2015                  NaN            NaN
# 229                       St. Lucia  2015                  NaN            NaN
# 230        St. Martin (French part)  2015                  NaN            NaN
# 231  St. Vincent and the Grenadines  2015                  NaN            NaN
# 232                           Sudan  2015             0.000000      22.618226
# 233                        Suriname  2015             0.000000      39.946856
# 234                          Sweden  2015            16.754050       0.155622
# 235                     Switzerland  2015             4.316383       0.068082
# 236            Syrian Arab Republic  2015             0.000000      29.064370
# 237                      Tajikistan  2015             0.000000       0.000000
# 238                        Tanzania  2015             0.667196      21.938046
# 239                        Thailand  2015             5.872525       0.570432
# 240                     Timor-Leste  2015                  NaN            NaN
# 241                            Togo  2015             6.172840      24.691358
# 242                           Tonga  2015                  NaN            NaN
# 243             Trinidad and Tobago  2015             0.000000       0.233010
# 244                         Tunisia  2015             2.485261       4.635088
# 245                          Turkey  2015             6.307132       0.849559
# 246                    Turkmenistan  2015             0.000000       0.000000
# 247        Turks and Caicos Islands  2015                  NaN            NaN
# 248                          Tuvalu  2015                  NaN            NaN
# 249                          Uganda  2015                  NaN            NaN
#
#      Nuclear Sources %  Coal Sources %  Natural Gas Sources %  \
# 200                NaN        0.000000               0.000000
# 201                NaN        0.839361              45.027046
# 202                NaN       44.514822              22.906580
# 203           0.000000       80.906165               3.886431
# 204           0.000000       28.718239              20.596322
# 205                NaN             NaN                    NaN
# 206                NaN        0.000000             100.000000
# 207                NaN       27.638725              14.238039
# 208                NaN       14.821658              49.712609
# 209                NaN             NaN                    NaN
# 210                NaN             NaN                    NaN
# 211                NaN             NaN                    NaN
# 212                NaN             NaN                    NaN
# 213                NaN        0.000000              55.803698
# 214                NaN        0.000000               4.171934
# 215                NaN       72.429844               0.579864
# 216                NaN             NaN                    NaN
# 217                NaN             NaN                    NaN
# 218                NaN        1.196073              95.029257
# 219                NaN             NaN                    NaN
# 220          56.871433       12.511265               6.022830
# 221          38.118378       29.594385               2.726598
# 222                NaN             NaN                    NaN
# 223                NaN             NaN                    NaN
# 224                NaN       92.711238               0.000000
# 225                NaN        0.000000               0.000000
# 226          20.618664       18.962389              18.898312
# 227                NaN       33.705052               0.000000
# 228                NaN             NaN                    NaN
# 229                NaN             NaN                    NaN
# 230                NaN             NaN                    NaN
# 231                NaN             NaN                    NaN
# 232                NaN        0.000000               0.000000
# 233                NaN        0.000000               0.000000
# 234          34.736400        0.666951               0.262457
# 235          34.931994        0.000000               1.001558
# 236                NaN        0.000000              68.625916
# 237                NaN        1.526629               0.000000
# 238                NaN        0.000000              43.907863
# 239                NaN       19.454320              71.436769
# 240                NaN             NaN                    NaN
# 241                NaN        0.000000               0.000000
# 242                NaN             NaN                    NaN
# 243                NaN        0.000000              99.766990
# 244                NaN        0.000000              91.441350
# 245           0.000000       29.095090              37.901239
# 246                NaN        0.000000             100.000000
# 247                NaN             NaN                    NaN
# 248                NaN             NaN                    NaN
# 249                NaN             NaN                    NaN
#
#      Hydroelectric Sources %
# 200                99.998206
# 201                49.140950
# 202                10.514118
# 203                 1.114755
# 204                16.887346
# 205                      NaN
# 206                 0.000000
# 207                25.231334
# 208                15.764769
# 209                      NaN
# 210                      NaN
# 211                      NaN
# 212                      NaN
# 213                 0.000000
# 214                 8.647282
# 215                26.812076
# 216                      NaN
# 217                      NaN
# 218                 0.000000
# 219                      NaN
# 220                14.516371
# 221                25.700209
# 222                      NaN
# 223                      NaN
# 224                 0.324638
# 225                 0.000000
# 226                10.129881
# 227                45.281444
# 228                      NaN
# 229                      NaN
# 230                      NaN
# 231                      NaN
# 232                64.535909
# 233                60.053144
# 234                46.508698
# 235                57.881598
# 236                 2.309714
# 237                98.473371
# 238                33.486894
# 239                 2.665954
# 240                      NaN
# 241                69.135802
# 242                      NaN
# 243                 0.000000
# 244                 0.350681
# 245                25.649488
# 246                 0.000000
# 247                      NaN
# 248                      NaN
# 249                      NaN

# %%
table_elec_source_breakdown.columns
#def rest(row):
#    if table_elec_source_breakdown[2]
table_elec_source_breakdown["rest"]= 100-table_elec_source_breakdown.iloc[:,2:8].fillna(0).apply(sum,axis=1)
table_elec_source_breakdown
# Out:
#                             Country  Year  Renewable Sources %  Oil Sources %  \
# 0                        Arab World  2015             0.454259      20.509818
# 1            Caribbean small states  2015                  NaN            NaN
# 2    Central Europe and the Baltics  2015            11.119740       0.854239
# 3        Early-demographic dividend  2015             3.566784       9.073565
# 4               East Asia & Pacific  2015             4.974811       1.681473
# ..                              ...   ...                  ...            ...
# 259           Virgin Islands (U.S.)  2015                  NaN            NaN
# 260              West Bank and Gaza  2015                  NaN            NaN
# 261                     Yemen, Rep.  2015             0.000000      60.195268
# 262                          Zambia  2015             0.000000       3.006176
# 263                        Zimbabwe  2015             1.328664       0.494387
#
#      Nuclear Sources %  Coal Sources %  Natural Gas Sources %  \
# 0                  NaN        1.519196              64.071422
# 1                  NaN             NaN                    NaN
# 2            13.653417       50.344621               7.101308
# 3             0.264383       36.528430              32.589130
# 4             1.946614       59.391846              13.524058
# ..                 ...             ...                    ...
# 259                NaN             NaN                    NaN
# 260                NaN             NaN                    NaN
# 261                NaN        0.000000              39.804732
# 262                NaN        0.000000               0.000000
# 263                NaN       46.781337               0.000000
#
#      Hydroelectric Sources %          rest
# 0                   2.438456  1.100685e+01
# 1                        NaN  1.000000e+02
# 2                   9.133112  7.793563e+00
# 3                  14.003280  3.974428e+00
# 4                  15.228439  3.252760e+00
# ..                       ...           ...
# 259                      NaN  1.000000e+02
# 260                      NaN  1.000000e+02
# 261                 0.000000  0.000000e+00
# 262                96.993824  2.842171e-14
# 263                51.395612  0.000000e+00
#
# [264 rows x 9 columns]

# %%
table_elec_access
# Out:
#                             Country  Year  Electricity Access WW  \
# 0                        Arab World  2018              89.286856
# 1            Caribbean small states  2018              98.401602
# 2    Central Europe and the Baltics  2018             100.000000
# 3        Early-demographic dividend  2018              90.724652
# 4               East Asia & Pacific  2018              97.986434
# ..                              ...   ...                    ...
# 259           Virgin Islands (U.S.)  2018             100.000000
# 260              West Bank and Gaza  2018             100.000000
# 261                     Yemen, Rep.  2018              62.000000
# 262                          Zambia  2018              39.812622
# 263                        Zimbabwe  2018              41.041584
#
#      Electricity Access Rural  Electricity Access Urban
# 0                   79.248100                 97.063959
# 1                   97.226735                 99.584314
# 2                  100.000000                 99.994298
# 3                   84.200218                 98.793351
# 4                   96.344871                 99.081422
# ..                        ...                       ...
# 259                100.000000                100.000000
# 260                100.000000                100.000000
# 261                 48.698349                 85.000000
# 262                 10.968000                 77.245483
# 263                 19.997750                 85.333015
#
# [264 rows x 5 columns]

# %%
#conversion table for c02emission depending on raw material source used

#20kwh of coal : 20000g
#20kwh of nuclear *: usually accepted to emit 70% less than diesel so : 3000g
#20kwh of natural gas : 10000 gCO2/100km
#20kwh renewable : < 1200g CO2/100km
    
#kg co2/kwh produced ---those values below are in kg,  . source https://www.eia.gov/tools/faqs/faq.php?id=74&t=11
coal_prod = 1002.439
nuclear_prod = 0.2*1002.439 #confirm
natural_gas_prod = 417.305
renewable_prod = 0.2*1002.439 #confirm
hydroelectric_prod = 0.2*1002.439 #confirm
oil_prod = 957.0799

# %%
#Nuclear Sources %	Coal Sources %	Natural Gas Sources %	Hydroelectric Sources

#for the conventional vehicle input 
country = input("where do you reside?")
habits= input("where do usually drive? city, highway or both ?) 
car = input("what conventional vehicle would you like to buy ?")
if car in cars2018_c["brand"]:
    
    cars["model"][cars2018_c["brand"] == car]
        
    model= input("what model would you chose from those listed above ?")
    co2emission=cars2018_c["CO2_gperkm"][cars2018_c["model"]==model
    print("the co2 emission for the car you chose equals "+ co2emission + " per kilometer")
        
region = input( "do you drive more in the city or highway or both")
                                         
#for the electrical vehicle input 
elec_car = input("what electrical vehicle would you like to buy?")
if elec_car in cars2018_c["brand"]:
   
   cars["model"][cars2018_c["brand"] == car]
                                         
   model= input("what model would you chose from those listed above ?")
   habits= input("where do usually drive? city, highway or both ?)
   if habits == "city":
                 
      co2emission = (cars2018_c["City_kwh_100km"][cars2018_c["model"]==model)/100
      co2final = co2emission + table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Oil Sources %"]/100
                +table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Nuclear Sources %"]/100 + 
                table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Coal Sources %"]/100
                +table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Natural Gas Sources %"]/100
                +table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Hydroelectric Sources %"]/100  
                                                  
   if habits == "highway":
                                                  
      co2emission = (cars2018_c["highway_kwh_100km"][cars2018_c["model"]==model)/100                                   
                                         
   if habits == "both":
                                                  
      co2emission = (cars2018_c["combined_kwh_100km"][cars2018_c["model"]==model)/100                                      
 
print("the co2 emission for the car you chose equals "+ co2emission + " per kilometer")
# Out:
#   File "<ipython-input-37-a5968bb459d0>", line 5
#     habits= input("where do usually drive? city, highway or both ?)
#                                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
cars2018_c["model"][cars2018_c["brand"] == "Jeep"]

# %%
cars2018_c["model"][cars2018_c["brand"] == "Tesla"].unique()

# %%
cars2018_c
# Out:
#                 make     id                         model  year     fuelType  \
# 0               Jeep  39861                  Cherokee FWD  2019     Midgrade
# 1               Jeep  39862                  Cherokee 4WD  2019     Midgrade
# 2               Jeep  39863  Cherokee 4WD Active Drive II  2019     Midgrade
# 3               Jeep  39864        Cherokee Trailhawk 4WD  2019     Midgrade
# 4          Chevrolet  39872                      Corvette  2019      Premium
# ...              ...    ...                           ...   ...          ...
# 3412     Lamborghini  43409       Aventador Sian Roadster  2020      Premium
# 3413     Lamborghini  43410          Aventador Sian Coupe  2020      Premium
# 3414  RUF Automobile  43411  TURBO12/CTR3/CTR ANNIVERSARY  2020      Premium
# 3415             Kia  43412                 Soul Electric  2020  Electricity
# 3416           Tesla  43413       Model X Long Range Plus  2020  Electricity
#
#                         evMotor  co2_per_km  comb08_per_km  combE_per_km  \
# 0                        filled  240.471249       9.778305      0.000000
# 1                        filled  248.549095       9.353162      0.000000
# 2                        filled  258.491058       8.928018      0.000000
# 3                        filled  268.433022       8.928018      0.000000
# 4                        filled  288.938323       8.077731      0.000000
# ...                         ...         ...            ...           ...
# 3412                     filled  535.001926       4.251437      0.000000
# 3413                     filled  535.001926       4.251437      0.000000
# 3414                     filled  308.822250       7.652587      0.000000
# 3415             201 kW AC PMSM    0.000000      48.466383     18.127431
# 3416  193 and 205 kW AC 3-Phase    0.000000      44.640090     19.981235
#
#       highway08_per_lkm  highwayE_per_km  UCity_per_lkm  UHighway_per_lkm  \
# 0             12.329168         0.000000      10.586078         17.429234
# 1             11.478880         0.000000      10.288478         16.495576
# 2             11.053737         0.000000       9.820820         15.750852
# 3             10.203449         0.000000       9.735621         14.752487
# 4             10.628593         0.000000       8.514353         15.075681
# ...                 ...              ...            ...               ...
# 3412           5.952012         0.000000       4.272354          8.148687
# 3413           5.952012         0.000000       4.272354          8.148687
# 3414           8.502874         0.000000       8.600657         11.746721
# 3415          42.939515        20.548859      78.779130         61.900925
# 3416          42.939515        20.793866      65.217046         60.582979
#
#           co2_km  cityE_100km
# 0     240.471249     0.000000
# 1     248.549095     0.000000
# 2     258.491058     0.000000
# 3     268.433022     0.000000
# 4     288.938323     0.000000
# ...          ...          ...
# 3412  535.001926     0.000000
# 3413  535.001926     0.000000
# 3414  308.822250     0.000000
# 3415    0.000000    16.146308
# 3416    0.000000    19.316304
#
# [3417 rows x 15 columns]

# %%
country="France"
habits= "city"
conv_car = "Jeep"
model = "Cherokee FWD"
elec_car = "Tesla"
model_e = "Model 3 Mid Range"

#Co2 emissions for conventional vehicle
co2emission=(cars2018_c["co2_per_km"][cars2018_c["model"]==model]).mean() #gives an answer in GRAM of co2 per KILOÑEMETER

#now lets calculate co2 for electric cars .. :)                                     
oil_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Oil Sources %"]/100
nuclear_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Nuclear Sources %"]/100
coal_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Coal Sources %"]/100
naturalgas_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Natural Gas Sources %"]/100
Hydro_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Hydroelectric Sources %"]/100
Renew_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Renewable Sources %"]/100
rest_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["rest"]/100
if habits == "city":
    kwhperkm= (cars2018_c["cityE_100km"][cars2018_c["model"]==model_e]/100).mean()
    co2emission_elec = kwhperkm*coal_source*coal_prod + kwhperkm*oil_source*oil_prod + kwhperkm*nuclear_prod*nuclear_source + kwhperkm*natural_gas_prod*naturalgas_source + kwhperkm*renewable_prod*Renew_source +kwhperkm*hydroelectric_prod*Hydro_source
    co2emission_elec += rest_source*co2emission_elec
    co2emission_elec_inclbatt=co2emission_elec + 52 #calculation explained in documents attached: battery co2

if habits == "highway":
    kwhperkm= (cars2018_c["highwayE_per_km"][cars2018_c["model"]==model_e]/100).mean()
    co2emission_elec = kwhperkm*coal_source*coal_prod + kwhperkm*oil_source*oil_prod + kwhperkm*nuclear_prod*nuclear_source + kwhperkm*natural_gas_prod*naturalgas_source + kwhperkm*renewable_prod*Renew_source +kwhperkm*hydroelectric_prod*Hydro_source
    co2emission_elec += rest_source*co2emission_elec
    co2emission_elec_inclbatt=co2emission_elec + 52

if habits == "combined":
    kwhperkm= (cars2018_c["combE_per_km"][cars2018_c["model"]==model_e]/100).mean()
    co2emission_elec = kwhperkm*coal_source*coal_prod + kwhperkm*oil_source*oil_prod + kwhperkm*nuclear_prod*nuclear_source + kwhperkm*natural_gas_prod*naturalgas_source + kwhperkm*renewable_prod*Renew_source +kwhperkm*hydroelectric_prod*Hydro_source
    co2emission_elec += rest_source*co2emission_elec
    co2emission_elec_inclbatt=co2emission_elec + 52    
    
print(co2emission)
print(co2emission_elec_inclbatt)
# Out:
# 224.52268217613016
# 115    89.472326
# dtype: float64

# %%
country="Belgium"
oil_source = table_elec_source_breakdown[table_elec_source_breakdown["Country"]==country]["Oil Sources %"]/100
oil_source

# %%
kwhperkm= (cars2018_c["City_kwh_100km"][cars2018_c["model"]==model_e]/100).mean()
kwhperkm
